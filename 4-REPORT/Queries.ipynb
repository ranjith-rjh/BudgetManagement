# %% [markdown]
# # 🔐 Styling

# %%
# %%HTML
# <style>
# body {
#     --vscode-font-family : 'Nasalization';
# }
#
# .dataframe {
#     font-family : 'Futura';
#     # font-family : 'Century Gothic';
#     border : 2px solid #252422;
#     border-radius : 5px;
#     overflow : hidden;
# }
#
# .dataframe tr th {
#     text-align : center;
# }
#
# .dataframe td {
#     paddign : 10px;
#     text-align : left;
# }
#
# .dataframe tr:hover{
#     background-color : #ef233c;
# }
#
# </style>
# Out:
# <style>
# body {
#     --vscode-font-family : 'Nasalization';
# }
#
# .dataframe {
#     font-family : 'Futura';
#     # font-family : 'Century Gothic';
#     border : 2px solid #252422;
#     border-radius : 5px;
#     overflow : hidden;
# }
#
# .dataframe tr th {
#     text-align : center;
# }
#
# .dataframe td {
#     paddign : 10px;
#     text-align : left;
# }
#
# .dataframe tr:hover{
#     background-color : #ef233c;
# }
#
# </style>

# %% [markdown]
# # 🛳️ Importation

# %%
import calendar
import datetime as dt

import psycopg2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns

# %% [markdown]
# # 🎯 Features

# %% [markdown]
# ## 📍 Connect database

# %%
# Create database connection

conn = ''

try :
    conn = psycopg2.connect(
        host = "localhost",
        port = "5432",
        user = "postgres",
        password = "postgres",
        dbname = "BudgetManagement"
    )    

except Exception as e: 
    print(e)

# Connect to Database and get informations
cursor = conn.cursor()

# %% [markdown]
# ## 📍 Functions

# %%
def get_data_from_query(query, cursor=cursor) : 
    cursor.execute(query)
    
    colnames = [col.name for col in cursor.description]
    rows = cursor.fetchall()

    data = pd.DataFrame(columns=colnames, data=rows)
    return data

# %% [markdown]
# # 📕 Data

# %% [markdown]
# ## 📜 vue_type_flux

# %%
query = f'''
SELECT * FROM vue_type_flux
'''

vue_type_flux = get_data_from_query(query)
vue_type_flux
# Out:
#    ID Type Flux   Type Flux
# 0             1      Entrée
# 1             2      Sortie
# 2             3      Neutre
# 3             4  Réparation

# %% [markdown]
# ## 📜 vue_periode

# %%
query = f'''
SELECT * FROM vue_periode
'''

vue_periode = get_data_from_query(query)
vue_periode
# Out:
#    ID Periode     Periode
# 0           1  Entreprise
# 1           2       Ecole
# 2           3    Vacances

# %% [markdown]
# ## 📜 vue_fixes

# %%
query = f'''
SELECT * FROM vue_fixes
'''

vue_fixes = get_data_from_query(query)
vue_fixes
# Out:
#    ID Fixes         Fixes
# 0         1          Fixe
# 1         2      Variable
# 2         3  Exceptionnel

# %% [markdown]
# ## 📜 vue_categorie

# %%
query = f'''
SELECT * FROM vue_categorie
'''

vue_categorie = get_data_from_query(query)
vue_categorie
# Out:
#     ID Categorie       Categorie     Target
# 0              1         Courses  100.00000
# 1              2            Mode          0
# 2              3      Esthétique          0
# 3              4         Hygiène          0
# 4              5      Abonnement          0
# 5              6      Transports          0
# 6              7        Logement          0
# 7              8            Aide          0
# 8              9  Divertissement          0
# 9             10         Emprunt          0
# 10            11          Emploi          0
# 11            12         Epargne          0
# 12            13          Impôts          0
# 13            14           Santé          0
# 14            15           Autre          0
# 15            16          Cadeau          0

# %% [markdown]
# ## 📜 vue_sous_categorie

# %%
query = f'''
SELECT * FROM vue_sous_categorie
'''

vue_sous_categorie = get_data_from_query(query)
vue_sous_categorie
# Out:
#      ID Categorie       Categorie  Sous-Categorie Target
# 0              17         Courses         Viandes      0
# 1              18         Courses        Fromages      0
# 2              19         Courses         Légumes      0
# 3              20         Courses          Fruits      0
# 4              21         Courses          Sauces      0
# ..            ...             ...             ...    ...
# 96            113         Epargne  Trade Republic      0
# 97            114         Courses             Sac      0
# 98            115  Divertissement       Bricolage      0
# 99            116         Courses             Eau      0
# 100           117      Esthétique          Parfum      0
#
# [101 rows x 4 columns]

# %%
vue_sous_categorie[vue_sous_categorie['Categorie'] == 'Transports']
# Out:
#     ID Categorie   Categorie      Sous-Categorie     Target
# 47            64  Transports           Carburant  150.00000
# 48            65  Transports        Huile Moteur          0
# 49            66  Transports  Assurance véhicule  130.00000
# 50            67  Transports              Garage          0
# 51            68  Transports  Entretien véhicule          0
# 52            69  Transports           Autoroute   25.00000
# 53            70  Transports                 Bus          0
# 54            71  Transports                Tram          0
# 55            72  Transports               Train          0
# 56            73  Transports               Avion          0
# 57            74  Transports         Covoiturage          0
# 58            75  Transports                Vélo          0
# 59            76  Transports             Parking          0

# %% [markdown]
# ## 📜 flux

# %%
query = f'''
SELECT * FROM flux
'''

flux = get_data_from_query(query)
flux
# Out:
#       id_flux  id_periode  id_type_flux  id_fixes  id_categorie   date_flux  \
# 0           1           1             2         2           102  2024-09-02
# 1           2           1             2         2            89  2024-09-02
# 2           3           1             1         1            98  2024-09-02
# 3           4           1             2         1            77  2024-09-02
# 4           6           1             2         2            87  2024-09-03
# ...       ...         ...           ...       ...           ...         ...
# 1270     1319           1             2         2            23  2025-12-02
# 1271     1320           1             2         2            18  2025-12-02
# 1272     1321           1             2         2            18  2025-12-02
# 1273     1322           1             2         2            28  2025-12-02
# 1274     1323           1             2         2            33  2025-12-02
#
#          montant             tags                      description
# 0      350.00000         #Epargne          Epargne août et réserve
# 1        9.00000          #Soirée              Soirée inté ENSIMAG
# 2     1329.00000         #Salaire                     Salaire août
# 3      390.00000           #Loyer             Loyer septembre 2024
# 4       16.00000    #Cheese #Naan         Cheese Naan après soirée
# ...          ...              ...                              ...
# 1270     2.95000     #chupa chups  Courses carrefour début du mois
# 1271     2.25000          #chèvre  Courses carrefour début du mois
# 1272     1.59000         #cheddar  Courses carrefour début du mois
# 1273     1.55000  #lays #barbecue  Courses carrefour début du mois
# 1274     1.89000     #yop #fraise  Courses carrefour début du mois
#
# [1275 rows x 9 columns]

# %%
flux[flux['id_flux'] == 1125]
# Out:
#       id_flux  id_periode  id_type_flux  id_fixes  id_categorie   date_flux  \
# 1102     1125           1             2         2           102  2025-10-01
#
#       montant      tags                             description
# 1102  4.73000  #epargne  Epargne pour faire 200€ sur septemebre

# %% [markdown]
# ## 📜 vue_flux

# %%
query = f'''
SELECT * FROM vue_flux
'''

vue_flux = get_data_from_query(query)
vue_flux
# Out:
#       ID Flux     Période Type de flux         Fixes       Catégorie  \
# 0           1  Entreprise       Sortie      Variable         Epargne
# 1           2  Entreprise       Sortie      Variable  Divertissement
# 2           3  Entreprise       Entrée          Fixe          Emploi
# 3           4  Entreprise       Sortie          Fixe        Logement
# 4           5  Entreprise       Sortie  Exceptionnel          Impôts
# ...       ...         ...          ...           ...             ...
# 1270     1319  Entreprise       Sortie      Variable         Courses
# 1271     1320  Entreprise       Sortie      Variable         Courses
# 1272     1321  Entreprise       Sortie      Variable         Courses
# 1273     1322  Entreprise       Sortie      Variable         Courses
# 1274     1323  Entreprise       Sortie      Variable         Courses
#
#      Sous-catégorie        Date     Montant             Tags  \
# 0          Livret A  2024-09-02   350.00000         #Epargne
# 1         Brasserie  2024-09-02     9.00000          #Soirée
# 2           Salaire  2024-09-02  1329.00000         #Salaire
# 3             Loyer  2024-09-02   390.00000           #Loyer
# 4            Impôts  2024-09-03   103.00000           #Ecole
# ...             ...         ...         ...              ...
# 1270       Sucrerie  2025-12-02     2.95000     #chupa chups
# 1271       Fromages  2025-12-02     2.25000          #chèvre
# 1272       Fromages  2025-12-02     1.59000         #cheddar
# 1273      Apéritifs  2025-12-02     1.55000  #lays #barbecue
# 1274           Lait  2025-12-02     1.89000     #yop #fraise
#
#                           Description
# 0             Epargne août et réserve
# 1                 Soirée inté ENSIMAG
# 2                        Salaire août
# 3                Loyer septembre 2024
# 4                       CVEC pour IUT
# ...                               ...
# 1270  Courses carrefour début du mois
# 1271  Courses carrefour début du mois
# 1272  Courses carrefour début du mois
# 1273  Courses carrefour début du mois
# 1274  Courses carrefour début du mois
#
# [1275 rows x 10 columns]

# %%
vue_flux[vue_flux['ID Flux'] == 1125]
# Out:
#       ID Flux     Période Type de flux     Fixes Catégorie Sous-catégorie  \
# 1076     1125  Entreprise       Sortie  Variable   Epargne       Livret A
#
#             Date  Montant      Tags                             Description
# 1076  2025-10-01  4.73000  #epargne  Epargne pour faire 200€ sur septemebre

# %% [markdown]
# ## 📜 vue_flux_mact

# %%
query = f'''
SELECT * FROM vue_flux_mact
'''

vue_flux_mact = get_data_from_query(query)
vue_flux_mact
# Out:
#     ID Flux     Période Type de flux     Fixes Catégorie Sous-catégorie  \
# 0      1308  Entreprise       Entrée  Variable    Emploi        Salaire
# 1      1309  Entreprise       Sortie  Variable   Epargne       Livret A
# 2      1310  Entreprise       Sortie      Fixe    Cadeau        Famille
# 3      1311  Entreprise       Sortie      Fixe  Logement          Loyer
# 4      1312  Entreprise       Sortie  Variable   Courses           Soda
# 5      1313  Entreprise       Sortie  Variable   Courses           Soda
# 6      1314  Entreprise       Sortie  Variable   Courses       Desserts
# 7      1315  Entreprise       Sortie  Variable   Courses       Desserts
# 8      1316  Entreprise       Sortie  Variable   Courses       Sucrerie
# 9      1317  Entreprise       Sortie  Variable   Courses       Sucrerie
# 10     1318  Entreprise       Sortie  Variable   Courses       Sucrerie
# 11     1319  Entreprise       Sortie  Variable   Courses       Sucrerie
# 12     1320  Entreprise       Sortie  Variable   Courses       Fromages
# 13     1321  Entreprise       Sortie  Variable   Courses       Fromages
# 14     1322  Entreprise       Sortie  Variable   Courses      Apéritifs
# 15     1323  Entreprise       Sortie  Variable   Courses           Lait
#
#           Date     Montant             Tags                      Description
# 0   2025-12-01  1913.25000         #salaire         Salaire mois de Novembre
# 1   2025-12-01   407.18000         #epargne            Epargne début du mois
# 2   2025-12-01   200.00000         #parents        Cadeau pour papa et maman
# 3   2025-12-01   390.00000           #loyer              Loyer decembre 2025
# 4   2025-12-02     2.39000            #coca  Courses carrefour début du mois
# 5   2025-12-02     2.39000            #coca  Courses carrefour début du mois
# 6   2025-12-02     1.75000         #danette  Courses carrefour début du mois
# 7   2025-12-02     3.99000         #yaourts  Courses carrefour début du mois
# 8   2025-12-02     1.75000           #loops  Courses carrefour début du mois
# 9   2025-12-02     1.99000        #biscuits  Courses carrefour début du mois
# 10  2025-12-02     2.35000   #haribo #croco  Courses carrefour début du mois
# 11  2025-12-02     2.95000     #chupa chups  Courses carrefour début du mois
# 12  2025-12-02     2.25000          #chèvre  Courses carrefour début du mois
# 13  2025-12-02     1.59000         #cheddar  Courses carrefour début du mois
# 14  2025-12-02     1.55000  #lays #barbecue  Courses carrefour début du mois
# 15  2025-12-02     1.89000     #yop #fraise  Courses carrefour début du mois

# %%
vue_flux_mact.iloc[-50:]
# Out:
#     ID Flux     Période Type de flux     Fixes Catégorie Sous-catégorie  \
# 0      1308  Entreprise       Entrée  Variable    Emploi        Salaire
# 1      1309  Entreprise       Sortie  Variable   Epargne       Livret A
# 2      1310  Entreprise       Sortie      Fixe    Cadeau        Famille
# 3      1311  Entreprise       Sortie      Fixe  Logement          Loyer
# 4      1312  Entreprise       Sortie  Variable   Courses           Soda
# 5      1313  Entreprise       Sortie  Variable   Courses           Soda
# 6      1314  Entreprise       Sortie  Variable   Courses       Desserts
# 7      1315  Entreprise       Sortie  Variable   Courses       Desserts
# 8      1316  Entreprise       Sortie  Variable   Courses       Sucrerie
# 9      1317  Entreprise       Sortie  Variable   Courses       Sucrerie
# 10     1318  Entreprise       Sortie  Variable   Courses       Sucrerie
# 11     1319  Entreprise       Sortie  Variable   Courses       Sucrerie
# 12     1320  Entreprise       Sortie  Variable   Courses       Fromages
# 13     1321  Entreprise       Sortie  Variable   Courses       Fromages
# 14     1322  Entreprise       Sortie  Variable   Courses      Apéritifs
# 15     1323  Entreprise       Sortie  Variable   Courses           Lait
#
#           Date     Montant             Tags                      Description
# 0   2025-12-01  1913.25000         #salaire         Salaire mois de Novembre
# 1   2025-12-01   407.18000         #epargne            Epargne début du mois
# 2   2025-12-01   200.00000         #parents        Cadeau pour papa et maman
# 3   2025-12-01   390.00000           #loyer              Loyer decembre 2025
# 4   2025-12-02     2.39000            #coca  Courses carrefour début du mois
# 5   2025-12-02     2.39000            #coca  Courses carrefour début du mois
# 6   2025-12-02     1.75000         #danette  Courses carrefour début du mois
# 7   2025-12-02     3.99000         #yaourts  Courses carrefour début du mois
# 8   2025-12-02     1.75000           #loops  Courses carrefour début du mois
# 9   2025-12-02     1.99000        #biscuits  Courses carrefour début du mois
# 10  2025-12-02     2.35000   #haribo #croco  Courses carrefour début du mois
# 11  2025-12-02     2.95000     #chupa chups  Courses carrefour début du mois
# 12  2025-12-02     2.25000          #chèvre  Courses carrefour début du mois
# 13  2025-12-02     1.59000         #cheddar  Courses carrefour début du mois
# 14  2025-12-02     1.55000  #lays #barbecue  Courses carrefour début du mois
# 15  2025-12-02     1.89000     #yop #fraise  Courses carrefour début du mois

# %% [markdown]
# ## 📜 vue_flux_sact

# %%
query = f'''
SELECT * FROM vue_flux_sact
'''

vue_flux_sact = get_data_from_query(query)
vue_flux_sact
# Out:
#     ID Flux     Période Type de flux     Fixes Catégorie Sous-catégorie  \
# 0      1308  Entreprise       Entrée  Variable    Emploi        Salaire
# 1      1309  Entreprise       Sortie  Variable   Epargne       Livret A
# 2      1310  Entreprise       Sortie      Fixe    Cadeau        Famille
# 3      1311  Entreprise       Sortie      Fixe  Logement          Loyer
# 4      1312  Entreprise       Sortie  Variable   Courses           Soda
# 5      1313  Entreprise       Sortie  Variable   Courses           Soda
# 6      1314  Entreprise       Sortie  Variable   Courses       Desserts
# 7      1315  Entreprise       Sortie  Variable   Courses       Desserts
# 8      1316  Entreprise       Sortie  Variable   Courses       Sucrerie
# 9      1317  Entreprise       Sortie  Variable   Courses       Sucrerie
# 10     1318  Entreprise       Sortie  Variable   Courses       Sucrerie
# 11     1319  Entreprise       Sortie  Variable   Courses       Sucrerie
# 12     1320  Entreprise       Sortie  Variable   Courses       Fromages
# 13     1321  Entreprise       Sortie  Variable   Courses       Fromages
# 14     1322  Entreprise       Sortie  Variable   Courses      Apéritifs
# 15     1323  Entreprise       Sortie  Variable   Courses           Lait
#
#           Date     Montant             Tags                      Description
# 0   2025-12-01  1913.25000         #salaire         Salaire mois de Novembre
# 1   2025-12-01   407.18000         #epargne            Epargne début du mois
# 2   2025-12-01   200.00000         #parents        Cadeau pour papa et maman
# 3   2025-12-01   390.00000           #loyer              Loyer decembre 2025
# 4   2025-12-02     2.39000            #coca  Courses carrefour début du mois
# 5   2025-12-02     2.39000            #coca  Courses carrefour début du mois
# 6   2025-12-02     1.75000         #danette  Courses carrefour début du mois
# 7   2025-12-02     3.99000         #yaourts  Courses carrefour début du mois
# 8   2025-12-02     1.75000           #loops  Courses carrefour début du mois
# 9   2025-12-02     1.99000        #biscuits  Courses carrefour début du mois
# 10  2025-12-02     2.35000   #haribo #croco  Courses carrefour début du mois
# 11  2025-12-02     2.95000     #chupa chups  Courses carrefour début du mois
# 12  2025-12-02     2.25000          #chèvre  Courses carrefour début du mois
# 13  2025-12-02     1.59000         #cheddar  Courses carrefour début du mois
# 14  2025-12-02     1.55000  #lays #barbecue  Courses carrefour début du mois
# 15  2025-12-02     1.89000     #yop #fraise  Courses carrefour début du mois

# %% [markdown]
# ## 📜 fs_total

# %%
keyword = 'carre'
date = '2025-12-02'

query = f'''
SELECT fs_total(\'{date}\', \'{keyword}\')
'''

fs_total = get_data_from_query(query)
fs_total
# Out:
#    fs_total
# 0  26.84000

# %% [markdown]
# ## 🔍 Explore

# %%
vue_flux_mact[vue_flux_mact['Catégorie'] == 'Cadeau']
# Out:
#    ID Flux     Période Type de flux Fixes Catégorie Sous-catégorie  \
# 2     1310  Entreprise       Sortie  Fixe    Cadeau        Famille
#
#          Date    Montant      Tags                Description
# 2  2025-12-01  200.00000  #parents  Cadeau pour papa et maman

# %% [markdown]
# # 🔄 Update

# %% [markdown]
# ## 🖍️ Date

# %%
id_flux = 0
date_flux = '2025-10-28'

query = f'''
UPDATE FLUX
SET date_flux = {date_flux}
WHERE id_flux = {id_flux}
'''

# cursor.execute(query)
