# %% [markdown]
# # 🔐 Styling

# %%
# %%HTML
# <style>
# body {
#     --vscode-font-family : 'Nasalization';
# }
#
# .dataframe {
#     font-family : 'Futura';
#     # font-family : 'Century Gothic';
#     border : 2px solid #252422;
#     border-radius : 5px;
#     overflow : hidden;
# }
#
# .dataframe tr th {
#     text-align : center;
# }
#
# .dataframe td {
#     paddign : 10px;
#     text-align : left;
# }
#
# .dataframe tr:hover{
#     background-color : #ef233c;
# }
#
# </style>
# Out:
# <style>
# body {
#     --vscode-font-family : 'Nasalization';
# }
#
# .dataframe {
#     font-family : 'Futura';
#     # font-family : 'Century Gothic';
#     border : 2px solid #252422;
#     border-radius : 5px;
#     overflow : hidden;
# }
#
# .dataframe tr th {
#     text-align : center;
# }
#
# .dataframe td {
#     paddign : 10px;
#     text-align : left;
# }
#
# .dataframe tr:hover{
#     background-color : #ef233c;
# }
#
# </style>

# %% [markdown]
# # 🛳️ Importation

# %%
import calendar
import datetime as dt

import psycopg2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns

# %% [markdown]
# # 🎯 Features

# %% [markdown]
# ## 📍 Connect database

# %%
# Create database connection

conn = ''

try :
    conn = psycopg2.connect(
        host = "localhost",
        port = "5432",
        user = "postgres",
        password = "postgres",
        dbname = "BudgetManagement"
    )    

except Exception as e: 
    print(e)

# Connect to Database and get informations
cursor = conn.cursor()

# %% [markdown]
# ## 📍 Functions

# %%
def get_data_from_query(query, cursor=cursor) : 
    cursor.execute(query)
    
    colnames = [col.name for col in cursor.description]
    rows = cursor.fetchall()

    data = pd.DataFrame(columns=colnames, data=rows)
    return data

# %% [markdown]
# # 📕 Data

# %% [markdown]
# ## 📜 vue_type_flux

# %%
query = f'''
SELECT * FROM vue_type_flux
'''

vue_type_flux = get_data_from_query(query)
vue_type_flux
# Out:
#    ID Type Flux   Type Flux
# 0             1      Entrée
# 1             2      Sortie
# 2             3      Neutre
# 3             4  Réparation

# %% [markdown]
# ## 📜 vue_periode

# %%
query = f'''
SELECT * FROM vue_periode
'''

vue_periode = get_data_from_query(query)
vue_periode
# Out:
#    ID Periode     Periode
# 0           1  Entreprise
# 1           2       Ecole
# 2           3    Vacances

# %% [markdown]
# ## 📜 vue_fixes

# %%
query = f'''
SELECT * FROM vue_fixes
'''

vue_fixes = get_data_from_query(query)
vue_fixes
# Out:
#    ID Fixes         Fixes
# 0         1          Fixe
# 1         2      Variable
# 2         3  Exceptionnel

# %% [markdown]
# ## 📜 vue_categorie

# %%
query = f'''
SELECT * FROM vue_categorie
'''

vue_categorie = get_data_from_query(query)
vue_categorie
# Out:
#     ID Categorie       Categorie     Target
# 0              1         Courses  100.00000
# 1              2            Mode          0
# 2              3      Esthétique          0
# 3              4         Hygiène          0
# 4              5      Abonnement          0
# 5              6      Transports          0
# 6              7        Logement          0
# 7              8            Aide          0
# 8              9  Divertissement          0
# 9             10         Emprunt          0
# 10            11          Emploi          0
# 11            12         Epargne          0
# 12            13          Impôts          0
# 13            14           Santé          0
# 14            15           Autre          0
# 15            16          Cadeau          0

# %% [markdown]
# ## 📜 vue_sous_categorie

# %%
query = f'''
SELECT * FROM vue_sous_categorie
'''

vue_sous_categorie = get_data_from_query(query)
vue_sous_categorie
# Out:
#      ID Categorie       Categorie  Sous-Categorie Target
# 0              17         Courses         Viandes      0
# 1              18         Courses        Fromages      0
# 2              19         Courses         Légumes      0
# 3              20         Courses          Fruits      0
# 4              21         Courses          Sauces      0
# ..            ...             ...             ...    ...
# 96            113         Epargne  Trade Republic      0
# 97            114         Courses             Sac      0
# 98            115  Divertissement       Bricolage      0
# 99            116         Courses             Eau      0
# 100           117      Esthétique          Parfum      0
#
# [101 rows x 4 columns]

# %% [markdown]
# ## 📜 flux

# %%
query = f'''
SELECT * FROM flux
'''

flux = get_data_from_query(query)
flux
# Out:
#       id_flux  id_periode  id_type_flux  id_fixes  id_categorie   date_flux  \
# 0           1           1             2         2           102  2024-09-02
# 1           2           1             2         2            89  2024-09-02
# 2           3           1             1         1            98  2024-09-02
# 3           4           1             2         1            77  2024-09-02
# 4           6           1             2         2            87  2024-09-03
# ...       ...         ...           ...       ...           ...         ...
# 1002     1051           2             2         2            69  2025-09-07
# 1003     1052           1             2         2            93  2025-09-08
# 1004     1053           1             2         2            20  2025-09-08
# 1005     1054           1             2         2            28  2025-09-08
# 1006     1055           1             2         2            29  2025-09-08
#
#          montant           tags               description
# 0      350.00000       #Epargne   Epargne août et réserve
# 1        9.00000        #Soirée       Soirée inté ENSIMAG
# 2     1329.00000       #Salaire              Salaire août
# 3      390.00000         #Loyer      Loyer septembre 2024
# 4       16.00000  #Cheese #Naan  Cheese Naan après soirée
# ...          ...            ...                       ...
# 1002    12.40000     #autoroute   Autoroute direction SMH
# 1003     8.50000     #croustine  Petit-déjeuner pour l'IT
# 1004     3.99000         #pomme         Courses carrefour
# 1005     1.69000         #chips         Courses carrefour
# 1006     4.08000       #perrier         Courses carrefour
#
# [1007 rows x 9 columns]

# %% [markdown]
# ## 📜 vue_flux

# %%
query = f'''
SELECT * FROM vue_flux
'''

vue_flux = get_data_from_query(query)
vue_flux
# Out:
#       ID Flux     Période Type de flux         Fixes       Catégorie  \
# 0           1  Entreprise       Sortie      Variable         Epargne
# 1           2  Entreprise       Sortie      Variable  Divertissement
# 2           3  Entreprise       Entrée          Fixe          Emploi
# 3           4  Entreprise       Sortie          Fixe        Logement
# 4           5  Entreprise       Sortie  Exceptionnel          Impôts
# ...       ...         ...          ...           ...             ...
# 1002     1051       Ecole       Sortie      Variable      Transports
# 1003     1052  Entreprise       Sortie      Variable  Divertissement
# 1004     1053  Entreprise       Sortie      Variable         Courses
# 1005     1054  Entreprise       Sortie      Variable         Courses
# 1006     1055  Entreprise       Sortie      Variable         Courses
#
#      Sous-catégorie        Date     Montant        Tags  \
# 0          Livret A  2024-09-02   350.00000    #Epargne
# 1         Brasserie  2024-09-02     9.00000     #Soirée
# 2           Salaire  2024-09-02  1329.00000    #Salaire
# 3             Loyer  2024-09-02   390.00000      #Loyer
# 4            Impôts  2024-09-03   103.00000      #Ecole
# ...             ...         ...         ...         ...
# 1002      Autoroute  2025-09-07    12.40000  #autoroute
# 1003    Boulangerie  2025-09-08     8.50000  #croustine
# 1004         Fruits  2025-09-08     3.99000      #pomme
# 1005      Apéritifs  2025-09-08     1.69000      #chips
# 1006           Soda  2025-09-08     4.08000    #perrier
#
#                    Description
# 0      Epargne août et réserve
# 1          Soirée inté ENSIMAG
# 2                 Salaire août
# 3         Loyer septembre 2024
# 4                CVEC pour IUT
# ...                        ...
# 1002   Autoroute direction SMH
# 1003  Petit-déjeuner pour l'IT
# 1004         Courses carrefour
# 1005         Courses carrefour
# 1006         Courses carrefour
#
# [1007 rows x 10 columns]

# %% [markdown]
# ## 📜 vue_flux_mact

# %%
query = f'''
SELECT * FROM vue_flux_mact
'''

vue_flux_mact = get_data_from_query(query)
vue_flux_mact
# Out:
#     ID Flux     Période Type de flux         Fixes       Catégorie  \
# 0      1032       Ecole       Entrée          Fixe          Emploi
# 1      1033       Ecole       Sortie          Fixe         Epargne
# 2      1034       Ecole       Sortie          Fixe          Cadeau
# 3      1035       Ecole       Sortie          Fixe        Logement
# 4      1036       Ecole       Sortie  Exceptionnel         Epargne
# 5      1037       Ecole       Entrée      Variable          Emploi
# 6      1038       Ecole       Sortie          Fixe      Abonnement
# 7      1039       Ecole       Sortie          Fixe      Abonnement
# 8      1040       Ecole       Sortie      Variable         Courses
# 9      1041       Ecole       Sortie      Variable  Divertissement
# 10     1042       Ecole       Sortie      Variable  Divertissement
# 11     1043       Ecole       Sortie      Variable  Divertissement
# 12     1044       Ecole       Sortie      Variable  Divertissement
# 13     1045       Ecole       Sortie      Variable  Divertissement
# 14     1046       Ecole       Sortie          Fixe      Transports
# 15     1047       Ecole       Entrée          Fixe            Aide
# 16     1048       Ecole       Sortie      Variable         Courses
# 17     1049       Ecole       Sortie      Variable      Transports
# 18     1050       Ecole       Sortie          Fixe      Abonnement
# 19     1051       Ecole       Sortie      Variable      Transports
# 20     1052  Entreprise       Sortie      Variable  Divertissement
# 21     1053  Entreprise       Sortie      Variable         Courses
# 22     1054  Entreprise       Sortie      Variable         Courses
# 23     1055  Entreprise       Sortie      Variable         Courses
#
#         Sous-catégorie        Date     Montant                Tags  \
# 0              Salaire  2025-09-01  2389.01000            #salaire
# 1             Livret A  2025-09-01   400.00000            #epargne
# 2              Famille  2025-09-01   200.00000        #papa #maman
# 3                Loyer  2025-09-01   390.00000              #loyer
# 4              Revolut  2025-09-01   200.00000            #etherum
# 5              Salaire  2025-09-03     4.00000           #business
# 6               Mobile  2025-09-01     0.99000             #icloud
# 7            Streaming  2025-09-03    14.99000            #netflix
# 8                  Jus  2025-09-03     7.41000              #pulco
# 9            Brasserie  2025-09-04     4.00000               #coca
# 10           Brasserie  2025-09-04    10.00000            #partie1
# 11           Brasserie  2025-09-04    10.00000            #partie2
# 12           Brasserie  2025-09-04     3.50000          #demi #moi
# 13           Brasserie  2025-09-04     7.00000  #demi #moi #arthur
# 14  Assurance véhicule  2025-09-05    78.82000              #flash
# 15                 CAF  2025-09-05   259.30000                #caf
# 16                 Eau  2025-09-03    18.98000          #decathlon
# 17           Carburant  2025-09-03    67.30000      #gazole #flash
# 18              Sports  2025-09-06    22.00000             #valseo
# 19           Autoroute  2025-09-07    12.40000          #autoroute
# 20         Boulangerie  2025-09-08     8.50000          #croustine
# 21              Fruits  2025-09-08     3.99000              #pomme
# 22           Apéritifs  2025-09-08     1.69000              #chips
# 23                Soda  2025-09-08     4.08000            #perrier
#
#                             Description
# 0        Dernier salaire contrat Tetras
# 1                 Epargne début de mois
# 2                  Cadeau papa et maman
# 3                  Loyer Septembre 2025
# 4             Pour investir sur Etherum
# 5                            BlaBla car
# 6                          Apple ICloud
# 7                               Netflix
# 8   Courses Hyper U Thoiry : Pulco etc.
# 9               Sortie le Bowl avec IAE
# 10              Sortie le Bowl avec IAE
# 11              Sortie le Bowl avec IAE
# 12                    Sortie Colloc Pub
# 13                    Sortie Colloc Pub
# 14           Assurance Macif pour Flash
# 15          Aide APL + Prime d'activité
# 16     Decathlon : Gourde et Mousqueton
# 17      Gazole  pour Flash après Thoiry
# 18                   Abonnement piscine
# 19              Autoroute direction SMH
# 20             Petit-déjeuner pour l'IT
# 21                    Courses carrefour
# 22                    Courses carrefour
# 23                    Courses carrefour

# %% [markdown]
# ## 📜 vue_flux_sact

# %%
query = f'''
SELECT * FROM vue_flux_sact
'''

vue_flux_sact = get_data_from_query(query)
vue_flux_sact
# Out:
#    ID Flux     Période Type de flux     Fixes       Catégorie Sous-catégorie  \
# 0     1052  Entreprise       Sortie  Variable  Divertissement    Boulangerie
# 1     1053  Entreprise       Sortie  Variable         Courses         Fruits
# 2     1054  Entreprise       Sortie  Variable         Courses      Apéritifs
# 3     1055  Entreprise       Sortie  Variable         Courses           Soda
#
#          Date  Montant        Tags               Description
# 0  2025-09-08  8.50000  #croustine  Petit-déjeuner pour l'IT
# 1  2025-09-08  3.99000      #pomme         Courses carrefour
# 2  2025-09-08  1.69000      #chips         Courses carrefour
# 3  2025-09-08  4.08000    #perrier         Courses carrefour
