# %% [markdown]
# # 🚢 Importation

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

project_path = 'R:/CODES/BudgetManagement'
data_path = os.path.join(project_path, '2 - DATA', 'BACKUP')

# %%
data_raw = pd.read_csv(os.path.join(data_path, 'VUE_FLUX.csv'), sep=';')
data_raw
# Out:
#      ID Flux     Période Type de flux         Fixes       Catégorie  \
# 0          1  Entreprise       Sortie      Variable         Epargne
# 1          2  Entreprise       Sortie      Variable  Divertissement
# 2          3  Entreprise       Entrée          Fixe          Emploi
# 3          4  Entreprise       Sortie          Fixe        Logement
# 4          5  Entreprise       Sortie  Exceptionnel          Impôts
# ..       ...         ...          ...           ...             ...
# 367      372  Entreprise       Sortie          Fixe      Transports
# 368      373  Entreprise       Sortie  Exceptionnel           Santé
# 369      374  Entreprise       Sortie      Variable  Divertissement
# 370      375  Entreprise       Sortie  Exceptionnel      Transports
# 371      376  Entreprise       Sortie  Exceptionnel      Transports
#
#          Sous-catégorie        Date  Montant       Tags  \
# 0              Livret A  2024-09-02   350.00   #Epargne
# ...

# %% [markdown]
# # 🎯 Main
